# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
import scipy
import statsmodels.api as sm
from datetime import datetime
from pathlib import Path
import os

pd.options.display.max_columns = None
pd.options.display.max_columns = 50

import warnings
warnings.filterwarnings(action="once")

# %% [markdown]
# # Reading in Dataframes + Preprocessing

# %%
COMMIT_HASH = "835aba8"
DATESTRING = datetime.strftime(datetime.today(), "%Y%m%d")

# DATA_DIR = f"../experiment_data_{COMMIT_HASH}/"
DATA_DIR = ".."
OUTPUT_DIR = f"../outputs/outputs_{DATESTRING}_{COMMIT_HASH}"
path = Path(OUTPUT_DIR)
path.mkdir(parents=True, exist_ok=True)

# DATAFILENAMES = os.listdir(DATA_DIR)
DATAFILENAMES = ["0123_results835aba8.pkl", "Jan21_summary3112ffd.pkl"]
print(DATAFILENAMES)

# DATAFILENAMES = [
#     "summary_reducedrank.pkl", 
#     "summary_tanh.pkl",
#     "summary_ffrelu.pkl",
#     "summary_tanh_zeromean.pkl"
# ]

# df_reducerank = pd.read_pickle(f"{DATA_DIR}/summary_reducedrank.pkl")
# df_tanh = pd.read_pickle(f"{DATA_DIR}/summary_tanh.pkl")
# df_relu = pd.read_pickle(f"{DATA_DIR}/summary_ffrelu.pkl")
# df_tanh_zeromean = pd.read_pickle(f"{DATA_DIR}/summary_tanh_zeromean.pkl")

DF_LIST = [
    pd.read_pickle(f"{DATA_DIR}/{filename}") for filename in DATAFILENAMES
]

COL_NUM_LAYERS = "num_layers"
COL_NUM_UNITS = "num_units"
COL_LOGN = "$\\log n$"
COL_LAMLOGN = "$-\\lambda \\log n$"
COL_H = "$H$"
COL_ELBO_S = "ELBO+$nS_n$"
COL_DIMW = "$dim_w$"
COL_DIMQ = "$dim_q$"
COL_LAMBDA = "$\\lambda$"
COL_SEED = "seed"
COL_ELBO_SHAT = "ELBO+$n\\hat S_n$"
COL_TESTLPD = "test_lpd"
COL_LR = "lr"

COL_MVFE = "normalized MVFE"
COL_VGE = "VGE"


FILENAME_PREFIX_DICT = {
    COL_ELBO_S: "ELBO_nS_vs_logn", 
    COL_ELBO_SHAT: "ELBO_nShat_vs_logn",
    COL_TESTLPD: f"{COL_TESTLPD}_vs_logn", 
    COL_MVFE: "MVFE_vs_logn", 
    COL_VGE: "VGE_vs_inverse_n",
}


def savefig(fig, filename):
    fig.savefig(os.path.join(OUTPUT_DIR, filename), bbox_inches="tight")
    return
# Out:
# ['0123_results835aba8.pkl', 'Jan21_summary3112ffd.pkl']

# %%
df_raw = pd.concat(DF_LIST)

rec = []
for method in df_raw["method"]:
    s = [entry.strip("\\") for entry in method.split("_")]
    num_layers, layer_width = s[-2:]
    m = s[0]
    rec.append([m, int(num_layers), int(layer_width)])

df_raw[["base_dist", COL_NUM_LAYERS, COL_NUM_UNITS]] = rec

INDEX_COLS = ["dataset", "base_dist", COL_NUM_LAYERS, COL_NUM_UNITS]

# %% [markdown]
# ## Filtering

# %%
# This is for old data where there is still a "ELBO + nSn" column
# max_elbo_in_expt = df_raw.groupby(INDEX_COLS + [COL_H, COL_LOGN]).aggregate("max")[COL_ELBO_S]
# max_elbo_in_expt.name = f"{COL_ELBO_S}_max"
# df_raw = df_raw.set_index(INDEX_COLS + [COL_H, COL_LOGN]).join(max_elbo_in_expt, how="left")
# df_raw["invalid"] = (
#     (np.log10(np.abs(df_raw[COL_ELBO_S] - df_raw[max_elbo_in_expt.name])) > 5)
#     | (df_raw[COL_ELBO_S] < -1e8)
# )

# df_data = df_raw.reset_index().set_index(INDEX_COLS)
# df_data[COL_LOGN] = np.around(df_data[COL_LOGN], decimals=4)
# df_data = df_data[~df_data["invalid"]]

# %%
fig, axes = plt.subplots(1, 2, figsize=(6, 3))

# threshold = 1e6
# df = df_raw[df_raw[COL_MVFE] < threshold]

df = None

groupby_cols = INDEX_COLS + [COL_H, COL_LOGN, COL_LR]
for name, g in df_raw.groupby(groupby_cols): 
    mean = np.mean(g[COL_MVFE])
    filter_flag = np.abs(g[COL_MVFE] - mean) / mean <= 0.8
    if df is None:
        df = g[filter_flag]
    else:
        df = pd.concat([df, g[filter_flag]])

ax = axes[0]
ax.hist(df_raw[COL_MVFE]);
ymin, ymax = ax.get_ylim()
# ax.vlines([threshold], ymin=ymin, ymax=ymax, color="r")
ax.set_yscale("log");
ax.set_title(f"Before filtering, nrows: {df_raw.shape[0]}")

ax = axes[1]
ax.hist(df[COL_MVFE]);
ax.set_yscale("log");
ax.set_title(f"After filtering, nrows: {df.shape[0]}")

df_data = df.set_index(INDEX_COLS)
df_data[COL_LOGN] = np.around(df_data[COL_LOGN], decimals=4)

# %% [markdown]
# ## Group dataframe and take statistics (e.g. mean, median, std, etc... ) over rng seeds

# %%
df_group = df_data.reset_index().groupby(
    INDEX_COLS + [COL_LR, COL_H, COL_LOGN]
).agg(["mean", "std", "min", "median", "max"])
df_group = df_group.reset_index().set_index(INDEX_COLS)
df_group
# Out:
# /var/folders/fz/r7njsjl97v705mmmwpjrd6g80000gn/T/ipykernel_5281/1130894268.py:1: FutureWarning: ['method'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_group = df_data.reset_index().groupby(
#                                                  lr  $H$ $\log n$ $dim_w$  \
#                                                                      mean
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          0.001    3   6.9078    42.0
#                                    4          0.001    3   7.0867    42.0
#                                    4          0.001    3   7.2661    42.0
#                                    4          0.001    3   7.4448    42.0
#                                    4          0.001    3   7.6241    42.0
# ...                                             ...  ...      ...     ...
# tanh_zeromean gengamma  4          16         0.001  280   7.8030   560.0
#                                    16         0.001  280   7.9824   560.0
#                                    16         0.001  280   8.1614   560.0
#                                    16         0.001  280   8.3405   560.0
#                                    16         0.001  280   8.5196   560.0
#
#                                                                    $\lambda$  \
#                                               std  min median  max      mean
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          0.0   42   42.0   42       NaN
#                                    4          0.0   42   42.0   42       NaN
#                                    4          0.0   42   42.0   42       NaN
#                                    4          0.0   42   42.0   42       NaN
#                                    4          0.0   42   42.0   42       NaN
# ...                                           ...  ...    ...  ...       ...
# tanh_zeromean gengamma  4          16         0.0  560  560.0  560  8.363636
#                                    16         0.0  560  560.0  560  8.363636
#                                    16         0.0  560  560.0  560  8.363636
#                                    16         0.0  560  560.0  560  8.363636
#                                    16         0.0  560  560.0  560  8.363636
#
#                                                                        \
#                                               std       min    median
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          NaN       NaN       NaN
#                                    4          NaN       NaN       NaN
#                                    4          NaN       NaN       NaN
#                                    4          NaN       NaN       NaN
#                                    4          NaN       NaN       NaN
# ...                                           ...       ...       ...
# tanh_zeromean gengamma  4          16         0.0  8.363636  8.363636
#                                    16         0.0  8.363636  8.363636
#                                    16         0.0  8.363636  8.363636
#                                    16         0.0  8.363636  8.363636
#                                    16         0.0  8.363636  8.363636
#
#                                                         seed                \
#                                                    max  mean       std min
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4               NaN  15.5  8.803408   1
#                                    4               NaN  15.5  8.803408   1
#                                    4               NaN  15.5  8.803408   1
#                                    4               NaN  15.5  8.803408   1
#                                    4               NaN  15.5  8.803408   1
# ...                                                ...   ...       ...  ..
# tanh_zeromean gengamma  4          16         8.363636  15.5  8.803408   1
#                                    16         8.363636  15.5  8.803408   1
#                                    16         8.363636  15.5  8.803408   1
#                                    16         8.363636  15.5  8.803408   1
#                                    16         8.363636  15.5  8.803408   1
#
#                                                           $dim_q$       \
#                                              median max      mean  std
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4           15.5  30    3376.0  0.0
#                                    4           15.5  30    3376.0  0.0
#                                    4           15.5  30    3376.0  0.0
#                                    4           15.5  30    3376.0  0.0
#                                    4           15.5  30    3376.0  0.0
# ...                                             ...  ..       ...  ...
# tanh_zeromean gengamma  4          16          15.5  30  304640.0  0.0
#                                    16          15.5  30  304640.0  0.0
#                                    16          15.5  30  304640.0  0.0
#                                    16          15.5  30  304640.0  0.0
#                                    16          15.5  30  304640.0  0.0
#
#                                                                         \
#                                                  min    median     max
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4            3376    3376.0    3376
#                                    4            3376    3376.0    3376
#                                    4            3376    3376.0    3376
#                                    4            3376    3376.0    3376
#                                    4            3376    3376.0    3376
# ...                                              ...       ...     ...
# tanh_zeromean gengamma  4          16         304640  304640.0  304640
#                                    16         304640  304640.0  304640
#                                    16         304640  304640.0  304640
#                                    16         304640  304640.0  304640
#                                    16         304640  304640.0  304640
#
#                                              grad_flag                     \
#                                                   mean  std    min median
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4               0.0  0.0  False    0.0
#                                    4               0.0  0.0  False    0.0
#                                    4               0.0  0.0  False    0.0
#                                    4               0.0  0.0  False    0.0
#                                    4               0.0  0.0  False    0.0
# ...                                                ...  ...    ...    ...
# tanh_zeromean gengamma  4          16              0.0  0.0  False    0.0
#                                    16              0.0  0.0  False    0.0
#                                    16              0.0  0.0  False    0.0
#                                    16              0.0  0.0  False    0.0
#                                    16              0.0  0.0  False    0.0
#
#                                                     $-\lambda \log n$       \
#                                                 max              mean  std
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          False       -145.062861  0.0
#                                    4          False       -148.821497  0.0
#                                    4          False       -152.588704  0.0
#                                    4          False       -156.341499  0.0
#                                    4          False       -160.106742  0.0
# ...                                             ...               ...  ...
# tanh_zeromean gengamma  4          16         False        -65.261677  0.0
#                                    16         False        -66.762028  0.0
#                                    16         False        -68.258773  0.0
#                                    16         False        -69.756541  0.0
#                                    16         False        -71.254755  0.0
#
#                                                                       \
#                                                      min      median
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4         -145.062861 -145.062861
#                                    4         -148.821497 -148.821497
#                                    4         -152.588704 -152.588704
#                                    4         -156.341499 -156.341499
#                                    4         -160.106742 -160.106742
# ...                                                  ...         ...
# tanh_zeromean gengamma  4          16         -65.261677  -65.261677
#                                    16         -66.762028  -66.762028
#                                    16         -68.258773  -68.258773
#                                    16         -69.756541  -69.756541
#                                    16         -71.254755  -71.254755
#
#                                                          normalized MVFE  \
#                                                      max            mean
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4         -145.062861      130.877730
#                                    4         -148.821497      139.174320
#                                    4         -152.588704      152.263973
#                                    4         -156.341499      173.500936
#                                    4         -160.106742      191.198885
# ...                                                  ...             ...
# tanh_zeromean gengamma  4          16         -65.261677      878.959587
#                                    16         -66.762028      904.481657
#                                    16         -68.258773      928.790137
#                                    16         -69.756541      956.250716
#                                    16         -71.254755      982.182682
#
#                                                                      \
#                                                     std         min
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          17.328562  115.408081
#                                    4          17.646549  121.653809
#                                    4          25.007414  130.615356
#                                    4          26.899015  149.679199
#                                    4          34.589823  158.643799
# ...                                                 ...         ...
# tanh_zeromean gengamma  4          16         10.796575  860.998779
#                                    16         10.993227  886.325684
#                                    16         11.914786  910.966309
#                                    16         11.607081  939.626465
#                                    16         11.526272  966.640625
#
#                                                                        \
#                                                   median          max
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          126.236694   200.979370
#                                    4          133.640869   212.666992
#                                    4          144.837524   251.307495
#                                    4          164.609619   281.168213
#                                    4          180.445679   325.382080
# ...                                                  ...          ...
# tanh_zeromean gengamma  4          16         876.522461   907.188721
#                                    16         901.776855   934.886230
#                                    16         925.208496   960.028809
#                                    16         952.497070   986.911133
#                                    16         977.941650  1017.155273
#
#                                                    VGE                      \
#                                                   mean       std       min
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          0.021525  0.004728  0.015261
#                                    4          0.024376  0.006390  0.016609
#                                    4          0.019030  0.005501  0.011156
#                                    4          0.016990  0.007287  0.009514
#                                    4          0.018228  0.008957  0.010754
# ...                                                ...       ...       ...
# tanh_zeromean gengamma  4          16         0.006992  0.002314  0.004323
#                                    16         0.004837  0.002066  0.002752
#                                    16         0.005364  0.002895  0.002819
#                                    16         0.003361  0.001805  0.001535
#                                    16         0.002980  0.001552  0.001561
#
#
#                                                 median       max
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          0.020686  0.038566
#                                    4          0.022914  0.043262
#                                    4          0.017495  0.034754
#                                    4          0.014899  0.035994
#                                    4          0.015090  0.046908
# ...                                                ...       ...
# tanh_zeromean gengamma  4          16         0.006106  0.012590
#                                    16         0.004035  0.010199
#                                    16         0.004195  0.013970
#                                    16         0.002940  0.009253
#                                    16         0.002615  0.008296
#
# [1280 rows x 43 columns]

# %% [markdown]
# ## Ascertain which learning rate is best for each (base dist, H, method) combo.

# %%
df = df_group.reset_index().set_index(INDEX_COLS + [COL_H, COL_LOGN])
# this is for old data format. 
# df = df.loc[:, [(COL_LR, ''), (COL_ELBO_S, "max"), (COL_ELBO_S, "mean"), (COL_ELBO_S, "median")]]

df = df.loc[:, [(COL_LR, ''), (COL_MVFE, "min"), (COL_MVFE, "mean"), (COL_MVFE, "median")]]

best_lr_rec = []
for idx in df.index.unique():
    x = df.loc[idx]
    best_lr = x.iloc[0, 0]
    best_data = tuple(x.iloc[0, 1:])
    for _, row in x.iterrows():
        row = np.array(row)
        if tuple(row[1:]) < best_data:
            best_lr = row[0].item()
            best_data = tuple(row[1:])
            
    best_lr_rec.append(list(idx) + [best_lr])

df_best_lr = pd.DataFrame(best_lr_rec, columns=list(df.index.names) + [COL_LR])
df_best_lr = df_best_lr.set_index(df.index.names)

sns.countplot(data=df_best_lr, x="lr")

df_best_lr
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[45], line 10
#       8 for idx in df.index.unique():
#       9     x = df.loc[idx]
# ---> 10     best_lr = x.iloc[0, 0]
#      11     best_data = tuple(x.iloc[0, 1:])
#      12     for _, row in x.iterrows():
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexing.py:869, in _LocationIndexer._validate_tuple_indexer(self, key)
#     864 @final
#     865 def _validate_tuple_indexer(self, key: tuple) -> tuple:
#     866     """
#     867     Check the key for valid keys across my indexer.
#     868     """
# --> 869     key = self._validate_key_length(key)
#     870     key = self._expand_ellipsis(key)
#     871     for i, k in enumerate(key):
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexing.py:908, in _LocationIndexer._validate_key_length(self, key)
#     906             raise IndexingError(_one_ellipsis_message)
#     907         return self._validate_key_length(key)
# --> 908     raise IndexingError("Too many indexers")
#     909 return key
#
# IndexingError: Too many indexers

# %% [markdown]
# ## Filter grouped dataframe with preferred learning rate

# %%
mode_rec = []

groupby_cols = ["dataset", "base_dist", COL_NUM_LAYERS, COL_NUM_UNITS, COL_H]

for idx, g in df_best_lr.reset_index().groupby(groupby_cols):
    preferred_lrs = list(g[COL_LR])
    chosen_lr = max(set(preferred_lrs), key=preferred_lrs.count) # mode of the lr's in the group. 
    mode_rec.append(list(idx) + [chosen_lr])
    

df_group = df_group.reset_index().set_index(groupby_cols + [COL_LR]).loc[mode_rec].reset_index().set_index(INDEX_COLS)
df_group
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 11
#       7     chosen_lr = max(set(preferred_lrs), key=preferred_lrs.count) # mode of the lr's in the group.
#       8     mode_rec.append(list(idx) + [chosen_lr])
# ---> 11 df_group = df_group.reset_index().set_index(groupby_cols + [COL_LR]).loc[mode_rec].reset_index().set_index(INDEX_COLS)
#      12 df_group
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexing.py:1239, in _LocIndexer._getitem_iterable(self, key, axis)
#    1236 self._validate_key(key, axis)
#    1238 # A collection of keys
# -> 1239 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240 return self.obj._reindex_with_indexers(
#    1241     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1242 )
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexing.py:1432, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1429 ax = self.obj._get_axis(axis)
#    1430 axis_name = self.obj._get_axis_name(axis)
# -> 1432 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434 return keyarr, indexer
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2626, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2623     self._raise_if_missing(key, indexer, axis_name)
#    2624     return self[indexer], indexer
# -> 2626 return super()._get_indexer_strict(key, axis_name)
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2646, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2644         raise KeyError(f"{keyarr} not in index")
#    2645 else:
# -> 2646     return super()._raise_if_missing(key, indexer, axis_name)
#
# File ~/.local/share/virtualenvs/variational-approximation-for-singular-mod-iNpIuKLj/lib/python3.9/site-packages/pandas/core/indexes/base.py:6173, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     if use_interval_msg:
#    6172         key = list(key)
# -> 6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [MultiIndex([(       'ffrelu', 'gaussian', 2,  4,   3,  0.01),\n            (       'ffrelu', 'gaussian', 2,  4,  10,  0.01),\n            (       'ffrelu', 'gaussian', 2,  4,  16,  0.01),\n            (       'ffrelu', 'gaussian', 2, 16,   3,  0.01),\n            (       'ffrelu', 'gaussian', 2, 16,  10,  0.01),\n            (       'ffrelu', 'gaussian', 2, 16,  16,  0.01),\n            (       'ffrelu', 'gaussian', 4,  4,   3,  0.01),\n            (       'ffrelu', 'gaussian', 4,  4,  10,  0.01),\n            (       'ffrelu', 'gaussian', 4,  4,  16,  0.01),\n            (       'ffrelu', 'gaussian', 4, 16,   3,  0.01),\n            (       'ffrelu', 'gaussian', 4, 16,  10,  0.01),\n            (       'ffrelu', 'gaussian', 4, 16,  16,  0.01),\n            (       'ffrelu', 'gengamma', 2,  4,   3,  0.01),\n            (       'ffrelu', 'gengamma', 2,  4,  10,  0.01),\n            (       'ffrelu', 'gengamma', 2,  4,  16,  0.01),\n            (       'ffrelu', 'gengamma', 2, 16,   3,  0.01),\n            (       'ffrelu', 'gengamma', 2, 16,  10,  0.01),\n            (       'ffrelu', 'gengamma', 2, 16,  16,  0.01),\n            (       'ffrelu', 'gengamma', 4,  4,   3,  0.01),\n            (       'ffrelu', 'gengamma', 4,  4,  10,  0.01),\n            (       'ffrelu', 'gengamma', 4,  4,  16,  0.01),\n            (       'ffrelu', 'gengamma', 4, 16,   3, 0.001),\n            (       'ffrelu', 'gengamma', 4, 16,  10,  0.01),\n            (       'ffrelu', 'gengamma', 4, 16,  16,  0.01),\n            (  'reducedrank', 'gaussian', 2,  4,   2,  0.01),\n            (  'reducedrank', 'gaussian', 2,  4,  16,  0.01),\n            (  'reducedrank', 'gaussian', 2,  4,  40,  0.01),\n            (  'reducedrank', 'gaussian', 2, 16,   2,  0.01),\n            (  'reducedrank', 'gaussian', 2, 16,  16,  0.01),\n            (  'reducedrank', 'gaussian', 2, 16,  40,  0.01),\n            (  'reducedrank', 'gaussian', 4,  4,   2,  0.01),\n            (  'reducedrank', 'gaussian', 4,  4,  16,  0.01),\n            (  'reducedrank', 'gaussian', 4,  4,  40,  0.01),\n            (  'reducedrank', 'gaussian', 4, 16,   2,  0.01),\n            (  'reducedrank', 'gaussian', 4, 16,  16,  0.01),\n            (  'reducedrank', 'gaussian', 4, 16,  40,  0.01),\n            (  'reducedrank', 'gengamma', 2,  4,   2,  0.01),\n            (  'reducedrank', 'gengamma', 2,  4,  16,  0.01),\n            (  'reducedrank', 'gengamma', 2,  4,  40,  0.01),\n            (  'reducedrank', 'gengamma', 2, 16,   2,  0.01),\n            (  'reducedrank', 'gengamma', 2, 16,  16, 0.001),\n            (  'reducedrank', 'gengamma', 2, 16,  40,  0.01),\n            (  'reducedrank', 'gengamma', 4,  4,   2,  0.01),\n            (  'reducedrank', 'gengamma', 4,  4,  16,  0.01),\n            (  'reducedrank', 'gengamma', 4,  4,  40,  0.01),\n            (  'reducedrank', 'gengamma', 4, 16,   2,  0.01),\n            (  'reducedrank', 'gengamma', 4, 16,  16, 0.001),\n            (  'reducedrank', 'gengamma', 4, 16,  40,  0.01),\n            (         'tanh', 'gaussian', 2,  4,  15,  0.01),\n            (         'tanh', 'gaussian', 2,  4, 115,  0.01),\n            (         'tanh', 'gaussian', 2,  4, 280,  0.01),\n            (         'tanh', 'gaussian', 2, 16,  15,  0.01),\n            (         'tanh', 'gaussian', 2, 16, 115,  0.01),\n            (         'tanh', 'gaussian', 2, 16, 280,  0.01),\n            (         'tanh', 'gaussian', 4,  4,  15,  0.01),\n            (         'tanh', 'gaussian', 4,  4, 115,  0.01),\n            (         'tanh', 'gaussian', 4,  4, 280,  0.01),\n            (         'tanh', 'gaussian', 4, 16,  15,  0.01),\n            (         'tanh', 'gaussian', 4, 16, 115,  0.01),\n            (         'tanh', 'gaussian', 4, 16, 280,  0.01),\n            (         'tanh', 'gengamma', 2,  4,  15,  0.01),\n            (         'tanh', 'gengamma', 2,  4, 115,  0.01),\n            (         'tanh', 'gengamma', 2,  4, 280,  0.01),\n            ...

# %% [markdown]
# ## Compute a "line score" for each (dataset, base dist, n, m, H) combination
# This will later help with de-cluttering the plots by ploting the lines with best score in each `(dataset, base dist, H)` combination

# %%
groupby_cols = INDEX_COLS + [COL_H]
group = df_group.groupby(groupby_cols)

rec = {}
for name, g in group:
    y = g[(COL_MVFE, "mean")]
    line_score = np.sum(np.abs(y))
    rec[name] = line_score

x = []
for idx, row in df_group.iterrows():
    key = tuple(list(idx) + [row[COL_H].item()])
    x.append(rec[key])
df_group["line_score"] = x
df_group
# Out:
#                                                  lr  $H$ $\log n$ $dim_w$  \
#                                                                      mean
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          0.001    3   6.9078    42.0
#                                    4          0.001    3   7.0867    42.0
#                                    4          0.001    3   7.2661    42.0
#                                    4          0.001    3   7.4448    42.0
#                                    4          0.001    3   7.6241    42.0
# ...                                             ...  ...      ...     ...
# tanh_zeromean gengamma  4          16         0.001  280   7.8030   560.0
#                                    16         0.001  280   7.9824   560.0
#                                    16         0.001  280   8.1614   560.0
#                                    16         0.001  280   8.3405   560.0
#                                    16         0.001  280   8.5196   560.0
#
#                                                                    $\lambda$  \
#                                               std  min median  max      mean
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          0.0   42   42.0   42       NaN
#                                    4          0.0   42   42.0   42       NaN
#                                    4          0.0   42   42.0   42       NaN
#                                    4          0.0   42   42.0   42       NaN
#                                    4          0.0   42   42.0   42       NaN
# ...                                           ...  ...    ...  ...       ...
# tanh_zeromean gengamma  4          16         0.0  560  560.0  560  8.363636
#                                    16         0.0  560  560.0  560  8.363636
#                                    16         0.0  560  560.0  560  8.363636
#                                    16         0.0  560  560.0  560  8.363636
#                                    16         0.0  560  560.0  560  8.363636
#
#                                                                        \
#                                               std       min    median
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          NaN       NaN       NaN
#                                    4          NaN       NaN       NaN
#                                    4          NaN       NaN       NaN
#                                    4          NaN       NaN       NaN
#                                    4          NaN       NaN       NaN
# ...                                           ...       ...       ...
# tanh_zeromean gengamma  4          16         0.0  8.363636  8.363636
#                                    16         0.0  8.363636  8.363636
#                                    16         0.0  8.363636  8.363636
#                                    16         0.0  8.363636  8.363636
#                                    16         0.0  8.363636  8.363636
#
#                                                         seed                \
#                                                    max  mean       std min
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4               NaN  15.5  8.803408   1
#                                    4               NaN  15.5  8.803408   1
#                                    4               NaN  15.5  8.803408   1
#                                    4               NaN  15.5  8.803408   1
#                                    4               NaN  15.5  8.803408   1
# ...                                                ...   ...       ...  ..
# tanh_zeromean gengamma  4          16         8.363636  15.5  8.803408   1
#                                    16         8.363636  15.5  8.803408   1
#                                    16         8.363636  15.5  8.803408   1
#                                    16         8.363636  15.5  8.803408   1
#                                    16         8.363636  15.5  8.803408   1
#
#                                                           $dim_q$       \
#                                              median max      mean  std
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4           15.5  30    3376.0  0.0
#                                    4           15.5  30    3376.0  0.0
#                                    4           15.5  30    3376.0  0.0
#                                    4           15.5  30    3376.0  0.0
#                                    4           15.5  30    3376.0  0.0
# ...                                             ...  ..       ...  ...
# tanh_zeromean gengamma  4          16          15.5  30  304640.0  0.0
#                                    16          15.5  30  304640.0  0.0
#                                    16          15.5  30  304640.0  0.0
#                                    16          15.5  30  304640.0  0.0
#                                    16          15.5  30  304640.0  0.0
#
#                                                                         \
#                                                  min    median     max
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4            3376    3376.0    3376
#                                    4            3376    3376.0    3376
#                                    4            3376    3376.0    3376
#                                    4            3376    3376.0    3376
#                                    4            3376    3376.0    3376
# ...                                              ...       ...     ...
# tanh_zeromean gengamma  4          16         304640  304640.0  304640
#                                    16         304640  304640.0  304640
#                                    16         304640  304640.0  304640
#                                    16         304640  304640.0  304640
#                                    16         304640  304640.0  304640
#
#                                              grad_flag                     \
#                                                   mean  std    min median
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4               0.0  0.0  False    0.0
#                                    4               0.0  0.0  False    0.0
#                                    4               0.0  0.0  False    0.0
#                                    4               0.0  0.0  False    0.0
#                                    4               0.0  0.0  False    0.0
# ...                                                ...  ...    ...    ...
# tanh_zeromean gengamma  4          16              0.0  0.0  False    0.0
#                                    16              0.0  0.0  False    0.0
#                                    16              0.0  0.0  False    0.0
#                                    16              0.0  0.0  False    0.0
#                                    16              0.0  0.0  False    0.0
#
#                                                     $-\lambda \log n$       \
#                                                 max              mean  std
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          False       -145.062861  0.0
#                                    4          False       -148.821497  0.0
#                                    4          False       -152.588704  0.0
#                                    4          False       -156.341499  0.0
#                                    4          False       -160.106742  0.0
# ...                                             ...               ...  ...
# tanh_zeromean gengamma  4          16         False        -65.261677  0.0
#                                    16         False        -66.762028  0.0
#                                    16         False        -68.258773  0.0
#                                    16         False        -69.756541  0.0
#                                    16         False        -71.254755  0.0
#
#                                                                       \
#                                                      min      median
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4         -145.062861 -145.062861
#                                    4         -148.821497 -148.821497
#                                    4         -152.588704 -152.588704
#                                    4         -156.341499 -156.341499
#                                    4         -160.106742 -160.106742
# ...                                                  ...         ...
# tanh_zeromean gengamma  4          16         -65.261677  -65.261677
#                                    16         -66.762028  -66.762028
#                                    16         -68.258773  -68.258773
#                                    16         -69.756541  -69.756541
#                                    16         -71.254755  -71.254755
#
#                                                          normalized MVFE  \
#                                                      max            mean
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4         -145.062861      130.877730
#                                    4         -148.821497      139.174320
#                                    4         -152.588704      152.263973
#                                    4         -156.341499      173.500936
#                                    4         -160.106742      191.198885
# ...                                                  ...             ...
# tanh_zeromean gengamma  4          16         -65.261677      878.959587
#                                    16         -66.762028      904.481657
#                                    16         -68.258773      928.790137
#                                    16         -69.756541      956.250716
#                                    16         -71.254755      982.182682
#
#                                                                      \
#                                                     std         min
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          17.328562  115.408081
#                                    4          17.646549  121.653809
#                                    4          25.007414  130.615356
#                                    4          26.899015  149.679199
#                                    4          34.589823  158.643799
# ...                                                 ...         ...
# tanh_zeromean gengamma  4          16         10.796575  860.998779
#                                    16         10.993227  886.325684
#                                    16         11.914786  910.966309
#                                    16         11.607081  939.626465
#                                    16         11.526272  966.640625
#
#                                                                        \
#                                                   median          max
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          126.236694   200.979370
#                                    4          133.640869   212.666992
#                                    4          144.837524   251.307495
#                                    4          164.609619   281.168213
#                                    4          180.445679   325.382080
# ...                                                  ...          ...
# tanh_zeromean gengamma  4          16         876.522461   907.188721
#                                    16         901.776855   934.886230
#                                    16         925.208496   960.028809
#                                    16         952.497070   986.911133
#                                    16         977.941650  1017.155273
#
#                                                    VGE                      \
#                                                   mean       std       min
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          0.021525  0.004728  0.015261
#                                    4          0.024376  0.006390  0.016609
#                                    4          0.019030  0.005501  0.011156
#                                    4          0.016990  0.007287  0.009514
#                                    4          0.018228  0.008957  0.010754
# ...                                                ...       ...       ...
# tanh_zeromean gengamma  4          16         0.006992  0.002314  0.004323
#                                    16         0.004837  0.002066  0.002752
#                                    16         0.005364  0.002895  0.002819
#                                    16         0.003361  0.001805  0.001535
#                                    16         0.002980  0.001552  0.001561
#
#                                                                    line_score
#                                                 median       max
# dataset       base_dist num_layers num_units
# ffrelu        gaussian  2          4          0.020686  0.038566  2103.101319
#                                    4          0.022914  0.043262  2103.101319
#                                    4          0.017495  0.034754  2103.101319
#                                    4          0.014899  0.035994  2103.101319
#                                    4          0.015090  0.046908  2103.101319
# ...                                                ...       ...          ...
# tanh_zeromean gengamma  4          16         0.006106  0.012590  8673.577189
#                                    16         0.004035  0.010199  8673.577189
#                                    16         0.004195  0.013970  8673.577189
#                                    16         0.002940  0.009253  8673.577189
#                                    16         0.002615  0.008296  8673.577189
#
# [1280 rows x 44 columns]

# %% [markdown]
# # Plotting

# %%
def _transpose_list(x):
    return list(map(list, zip(*x)))

# %%
dataset_types = sorted(set([x[0] for x in df_data.index]))
# plot_grid = []
# for dataset in dataset_types:
#     df = df_data.loc[dataset]
#     row = []
#     for h in sorted(df[COL_H].unique()):
#         row.append((dataset, h))
#     plot_grid.append(row)
plot_grid = [
    [("ffrelu", 40, COL_MVFE), ("ffrelu", 40, COL_VGE), ], 
    [("reducedrank", 16, COL_MVFE), ("reducedrank", 16, COL_VGE)], 
    [("tanh", 280, COL_MVFE), ("tanh", 280, COL_VGE)]
]
# plot_grid = _transpose_list(plot_grid)

num_rows = len(plot_grid)
num_cols = len(plot_grid[0])
fig, axes = plt.subplots(num_rows, num_cols, figsize=(6 * num_cols, 6 * num_rows), sharex=False)
if len(axes.shape) == 1:
    axes = axes.reshape(-1, 1)

basedist_color_map = {
    "gengamma": "Greens",
    "gaussian": "Reds"
}


PLOT_ONLY = [
    "gengamma", 
    "gaussian"
]

PLOT_BEST_LINE_ONLY = False

idx_filtered = df_group.index.get_level_values(1).isin(PLOT_ONLY)
df_plot = df_group[idx_filtered]

if PLOT_BEST_LINE_ONLY: 
    df_chosen = None
    groupby_cols = ["dataset", "base_dist", COL_H]
    for name, df in df_plot.groupby(groupby_cols):
        chosen_rows = df[df["line_score"] == df["line_score"].min()]
        if df_chosen is None:
            df_chosen = chosen_rows
        else:
            df_chosen = pd.concat([df_chosen, chosen_rows])
    df_plot = df_chosen


# PLOT_YVAR = COL_ELBO_SHAT
# PLOT_YVAR = COL_ELBO_S
# PLOT_YVAR = COL_TESTLPD
# PLOT_YVAR = COL_MVFE
PLOT_YVAR = COL_VGE

PLOT_STATS = "mean"

slope_var_name_dict = {
    COL_MVFE: "$\\hat{\\lambda}_{vfe}$", 
    COL_VGE: "$\\hat{\\lambda}_{vge}$", 
}
SLOPE_VAR_NAME = slope_var_name_dict.get(PLOT_YVAR, "slope")

PLOT_TRUE_LAMBDA_LINE = False
PLOT_LEAST_SQUARE_LINE = True
FORCE_ZERO_INTERCEPT = False

rec = []
for i in range(num_rows):
    for j in range(num_cols):
#         dataset, h = plot_grid[i][j]
        dataset, h, PLOT_YVAR = plot_grid[i][j]
        ax = axes[i][j]
        df = df_plot.loc[dataset]
        df = df[df[COL_H] == h]
        complexities = sorted(set(zip(df.reset_index()[COL_NUM_LAYERS], df.reset_index()[COL_NUM_UNITS])))
        lambda_logn_plotted = False
        
        for idx in df.index.unique():
            base_dist, n, m = idx
            # Pulling out relevant columns / quantities
            x = df.loc[idx, COL_LOGN]
            xlabel = COL_LOGN
            if PLOT_YVAR in [COL_TESTLPD, COL_VGE]:
                x = 1 / np.exp(x)
                xlabel = "1/n"

            y = df.loc[idx, (PLOT_YVAR, PLOT_STATS)]
            y2 = df.loc[idx, (COL_LAMLOGN, PLOT_STATS)]
            
#             e = df.loc[idx, (PLOT_YVAR, "std")]
            e_min = df.loc[idx, (PLOT_YVAR, "min")]
            e_max = df.loc[idx, (PLOT_YVAR, "max")]
            e = np.abs(np.array([e_min, e_max]) - np.array([y]))
            
            lmbda = df[(COL_LAMBDA, PLOT_STATS)]
            cmap = matplotlib.colormaps[basedist_color_map[base_dist]]
            c = cmap((complexities.index((n, m)) + 1) / len(complexities))
            if PLOT_LEAST_SQUARE_LINE:
                linefit_result = sm.OLS(np.array(y), np.array(x)).fit()
                if FORCE_ZERO_INTERCEPT:
                    slope = linefit_result.params[0]
                    intercept = 0
                    rsquared_value = linefit_result.rsquared
                else:
                    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
                    rsquared_value = r_value ** 2
                
                ax.plot(x, intercept + slope * x, linestyle="dashed", color=c, alpha=0.8)
                lr = df.loc[idx, COL_LR].values[0]
                slope_var_name = slope_var_name_dict.get(PLOT_YVAR, "slope")
                label = (
                    f"{base_dist}_{n}_{m},"
#                     f" lr={lr:.3f},"
                    f" $R^2$={np.around(rsquared_value, 2)},"
                    f" {slope_var_name}={np.around(slope, 2)}"
                )
            else:
                label = f"{base_dist}_{n}_{m}"
                slope = intercept = rsquared_value = None
            
            rec.append([dataset, base_dist, n, m, h, slope, intercept, rsquared_value, lmbda[0]])
            ax.errorbar(
                x, y, 
                fmt="x-",
                yerr=e, 
                capsize=5,
                elinewidth=1, 
                capthick=1,
                label=label, 
                color=c
            )
            
            if not lambda_logn_plotted and PLOT_TRUE_LAMBDA_LINE:
                ax.plot(x, y2, color="blue", label=COL_LAMLOGN)
                lambda_logn_plotted = True
            ax.legend(prop={"size": 7})
            ax.set_title(f"{dataset}, H={h}")
            ax.set_xlabel(xlabel)
            ax.set_ylabel(PLOT_YVAR)
            if PLOT_YVAR == COL_VGE:
                ax.ticklabel_format(axis="x", style="scientific", scilimits=(0, 0), useMathText=True)


image_filename = FILENAME_PREFIX_DICT.get(PLOT_YVAR, None)
if image_filename is not None:
    image_filename += f"_{'_'.join(PLOT_ONLY)}"
    if PLOT_BEST_LINE_ONLY:
        image_filename += "_best_line_only"
    image_filename = "experiment_result_plots_vertical"
    image_filename += ".png"
    print(f"Image filename: {image_filename}")
    savefig(fig, image_filename)
# Out:
# Image filename: experiment_result_plots_vertical.png

# %%
df_rec = pd.DataFrame(
    rec, 
    columns=[
        "dataset", "base_dist", 
        COL_NUM_LAYERS, COL_NUM_UNITS, 
        COL_H, SLOPE_VAR_NAME, 
        "intercept", "$R^2$-value", "$\\lambda$"
    ]
)
df_rec["diff"] = np.abs(df_rec[SLOPE_VAR_NAME] + df_rec["$\\lambda$"])
df_rec = df_rec.set_index(["dataset", COL_H])

df_result = None
for idx in df_rec.index.unique():
    if df_result is None:
        df_result = df_rec.loc[idx].sort_values("diff")
    else:
        df_result = pd.concat([df_result, df_rec.loc[idx].sort_values("diff")])


filename = FILENAME_PREFIX_DICT.get(PLOT_YVAR, None)
if filename is not None:
    filename += "_least_square_fit_results.csv"
    print(f"filename: {filename}")
    df_result.to_csv(f"{OUTPUT_DIR}/{filename}")

df_result
# Out:
# filename: MVFE_vs_logn_least_square_fit_results.csv
#                   base_dist  num_layers  num_units  $\hat{\lambda}_{vfe}$  \
# dataset       $H$
# ffrelu        3    gaussian           2          4             121.780168
#               3    gaussian           2         16              86.526500
#               3    gaussian           4          4              51.914127
#               3    gaussian           4         16              24.251203
#               3    gengamma           2          4              28.129190
# ...                     ...         ...        ...                    ...
# tanh_zeromean 280  gaussian           4         16             146.559584
#               280  gaussian           4          4             171.293897
#               280  gengamma           2          4             192.136937
#               280  gaussian           2          4             228.156260
#               280  gengamma           4          4             235.370084
#
#                     intercept  $R^2$-value  $\lambda$        diff
# dataset       $H$
# ffrelu        3   -729.058246     0.957745        NaN         NaN
#               3   -504.006310     0.944076        NaN         NaN
#               3   -272.319800     0.969746        NaN         NaN
#               3    -96.637461     0.867872        NaN         NaN
#               3   -116.343054     0.892683        NaN         NaN
# ...                       ...          ...        ...         ...
# tanh_zeromean 280 -298.149839     0.999690   8.363636  154.923221
#               280 -435.338383     0.998145   8.363636  179.657533
#               280 -517.762156     0.999401   8.363636  200.500573
#               280 -844.736951     0.980224   8.363636  236.519896
#               280 -808.715547     0.997115   8.363636  243.733721
#
# [128 rows x 8 columns]

# %% [markdown]
# # Summarising table

# %%
df = df_data.reset_index()

gcols = ["dataset", COL_H, COL_DIMW, COL_LAMBDA]
g = df.groupby(gcols)
dfx = pd.DataFrame([x for x in g.groups.keys()], columns=gcols)
dfx[COL_LAMBDA] = np.around(dfx[COL_LAMBDA], 2)
dfx[COL_LAMBDA].fillna("-", inplace=True)


io_dims_rec = {
    "tanh": (1, 1), 
    "tanh_zeromean": (1, 1), 
    "ffrelu": (13, 1),
    "reducedrank": (3, 0), 
}

io_dims = []
for i, row in dfx.iterrows():
    dset = row["dataset"]
    xdim, ydim = io_dims_rec[dset]
    if dset == "reducedrank":
        xdim += row[COL_H]
        ydim += row[COL_H]
    io_dims.append((xdim, ydim))

dfx[["dim(x)", "dim(y)"]] = io_dims

def _formatter(name):
    if name == "tanh_zeromean":
        return "tanh (zero mean)"
    return name

dfx["dataset"] = [_formatter(name) for name in dfx["dataset"]]
dfx = dfx.set_index(gcols[:2]).sort_index()
dfx
# Out:
#                       $dim_w$ $\lambda$  dim(x)  dim(y)
# dataset          $H$
# ffrelu           3         42         -      13       1
#                  7         98         -      13       1
#                  16       224         -      13       1
#                  40       560         -      13       1
# reducedrank      2         14       5.0       5       2
#                  7        119      35.0      10       7
#                  10       230      65.0      13      10
#                  16       560     152.0      19      16
# tanh             15        30         -       1       1
#                  50       100         -       1       1
#                  115      230         -       1       1
#                  280      560         -       1       1
# tanh (zero mean) 15        30      1.93       1       1
#                  50       100      3.53       1       1
#                  115      230      5.36       1       1
#                  280      560      8.36       1       1

# %%
print(dfx.to_latex(index=True, escape=False, formatters={"dataset": _formatter}))
# Out:
# \begin{tabular}{llrlrr}
# \toprule
#                  &     &  $dim_w$ & $\lambda$ &  dim(x) &  dim(y) \\
# dataset & $H$ &          &           &         &         \\
# \midrule
# ffrelu & 3   &       42 &         - &      13 &       1 \\
#                  & 7   &       98 &         - &      13 &       1 \\
#                  & 16  &      224 &         - &      13 &       1 \\
#                  & 40  &      560 &         - &      13 &       1 \\
# reducedrank & 2   &       14 &       5.0 &       5 &       2 \\
#                  & 7   &      119 &      35.0 &      10 &       7 \\
#                  & 10  &      230 &      65.0 &      13 &      10 \\
#                  & 16  &      560 &     152.0 &      19 &      16 \\
# tanh & 15  &       30 &         - &       1 &       1 \\
#                  & 50  &      100 &         - &       1 &       1 \\
#                  & 115 &      230 &         - &       1 &       1 \\
#                  & 280 &      560 &         - &       1 &       1 \\
# tanh (zero mean) & 15  &       30 &      1.93 &       1 &       1 \\
#                  & 50  &      100 &      3.53 &       1 &       1 \\
#                  & 115 &      230 &      5.36 &       1 &       1 \\
#                  & 280 &      560 &      8.36 &       1 &       1 \\
# \bottomrule
# \end{tabular}
# /var/folders/fz/r7njsjl97v705mmmwpjrd6g80000gn/T/ipykernel_5281/3566097837.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(dfx.to_latex(index=True, escape=False, formatters={"dataset": _formatter}))

# %%
df = df_data.reset_index()
gcols = ["base_dist", "num_layers", "num_units", COL_DIMQ]
cols  = ["Base distribution", "Num coupling layers", "Num units", COL_DIMQ]
g = df.groupby(gcols)
dfx = pd.DataFrame([x for x in g.groups.keys()], columns=cols).set_index(cols[:3])
dfx
# Out:
#                                                  $dim_q$
# Base distribution Num coupling layers Num units
# gaussian          2                   4             1360
#                                       4             2512
#                                       4             3376
#                                       4             7408
#                                       4             7552
# ...                                                  ...
# gengamma          4                   16           61760
#                                       16           71792
#                                       16          127232
#                                       16          130400
#                                       16          304640
#
# [72 rows x 1 columns]

# %%
print(dfx.to_latex(index=True, escape=False))
# Out:
# \begin{tabular}{lllr}
# \toprule
#          &   &    &  $dim_q$ \\
# Base distribution & Num coupling layers & Num units &          \\
# \midrule
# gaussian & 2 & 4  &     1360 \\
#          &   & 4  &     2512 \\
#          &   & 4  &     3376 \\
#          &   & 4  &     7408 \\
#          &   & 4  &     7552 \\
#          &   & 4  &     8920 \\
#          &   & 4  &    16480 \\
#          &   & 4  &    16912 \\
#          &   & 4  &    40672 \\
#          &   & 16 &     8176 \\
#          &   & 16 &    12400 \\
#          &   & 16 &    15568 \\
#          &   & 16 &    30352 \\
#          &   & 16 &    30880 \\
#          &   & 16 &    35896 \\
#          &   & 16 &    63616 \\
#          &   & 16 &    65200 \\
#          &   & 16 &   152320 \\
#          & 4 & 4  &     2720 \\
#          &   & 4  &     5024 \\
#          &   & 4  &     6752 \\
#          &   & 4  &    14816 \\
#          &   & 4  &    15104 \\
#          &   & 4  &    17840 \\
#          &   & 4  &    32960 \\
#          &   & 4  &    33824 \\
#          &   & 4  &    81344 \\
#          &   & 16 &    16352 \\
#          &   & 16 &    24800 \\
#          &   & 16 &    31136 \\
#          &   & 16 &    60704 \\
#          &   & 16 &    61760 \\
#          &   & 16 &    71792 \\
#          &   & 16 &   127232 \\
#          &   & 16 &   130400 \\
#          &   & 16 &   304640 \\
# gengamma & 2 & 4  &     1360 \\
#          &   & 4  &     2512 \\
#          &   & 4  &     3376 \\
#          &   & 4  &     7408 \\
#          &   & 4  &     7552 \\
#          &   & 4  &     8920 \\
#          &   & 4  &    16480 \\
#          &   & 4  &    16912 \\
#          &   & 4  &    40672 \\
#          &   & 16 &     8176 \\
#          &   & 16 &    12400 \\
#          &   & 16 &    15568 \\
#          &   & 16 &    30352 \\
#          &   & 16 &    30880 \\
#          &   & 16 &    35896 \\
#          &   & 16 &    63616 \\
#          &   & 16 &    65200 \\
#          &   & 16 &   152320 \\
#          & 4 & 4  &     2720 \\
#          &   & 4  &     5024 \\
#          &   & 4  &     6752 \\
#          &   & 4  &    14816 \\
#          &   & 4  &    15104 \\
#          &   & 4  &    17840 \\
#          &   & 4  &    32960 \\
#          &   & 4  &    33824 \\
#          &   & 4  &    81344 \\
#          &   & 16 &    16352 \\
#          &   & 16 &    24800 \\
#          &   & 16 &    31136 \\
#          &   & 16 &    60704 \\
#          &   & 16 &    61760 \\
#          &   & 16 &    71792 \\
#          &   & 16 &   127232 \\
#          &   & 16 &   130400 \\
#          &   & 16 &   304640 \\
# \bottomrule
# \end{tabular}
# /var/folders/fz/r7njsjl97v705mmmwpjrd6g80000gn/T/ipykernel_5281/2149175323.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(dfx.to_latex(index=True, escape=False))
